# %% [markdown]
# ### Spatial Analysis of UK Local Authority Districts (LADs)

# %%
#importing libraries
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load shapefiles
# LAD: Local Athority Districts 
# ITL1: UK regions (12 regions)

in_shp = r'data\Local_Authority_Districts_May_2024_Boundaries_UK_BGC_-5850961694214429102\LAD_MAY_2024_UK_BGC.shp'
lad_gdf = gpd.read_file(in_shp)

itl1_gdf = gpd.read_file(r'data\ITL1_JAN_2025_UK_BUC_3847796120714293736\ITL1_JAN_2025_UK_BUC.shp')

# %%
#Check CRS
print('UK LAD CRS: ',lad_gdf.crs)
print('ITL1 CRS: ', itl1_gdf.crs)
# Out:
# UK LAD CRS:  EPSG:27700
# ITL1 CRS:  EPSG:27700

# %%
lad_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LAD24CD   361 non-null    object
#  1   LAD24NM   361 non-null    object
#  2   LAD24NMW  22 non-null     object
#  3   BNG_E     361 non-null    int64
#  4   BNG_N     361 non-null    int64
#  5   LONG      361 non-null    float64
#  6   LAT       361 non-null    float64
#  7   GlobalID  361 non-null    object
#  8   geometry  361 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(4)
# memory usage: 25.5+ KB

# %%
itl1_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ITL125CD  12 non-null     object
#  1   ITL125NM  12 non-null     object
#  2   BNG_E     12 non-null     float64
#  3   BNG_N     12 non-null     float64
#  4   LAT       12 non-null     float64
#  5   LONG      12 non-null     float64
#  6   GlobalID  12 non-null     object
#  7   geometry  12 non-null     geometry
# dtypes: float64(4), geometry(1), object(3)
# memory usage: 900.0+ bytes

# %%
itl1_gdf.head()
# Out:
#   ITL125CD                  ITL125NM     BNG_E     BNG_N       LAT     LONG  \
# 0      TLC      North East (England)  417317.0  575393.0  55.07271 -1.73036
# 1      TLD      North West (England)  349989.0  463422.0  54.06431 -2.76560
# 2      TLE  Yorkshire and The Humber  452737.0  445838.0  53.90604 -1.19878
# 3      TLF   East Midlands (England)  477748.0  322635.0  52.79571 -0.84837
# 4      TLG   West Midlands (England)  386293.0  295477.0  52.55697 -2.20360
#
#                                GlobalID  \
# 0  33c985b2-6025-4a45-822b-dd94a559046b
# 1  0eff8897-1a46-48cc-80be-503c33840ef3
# 2  d83d3af4-9631-4736-bb2c-3473ddd636fa
# 3  1ceaa16b-08a7-40ae-b749-c0376b3f68b2
# 4  778f3e42-f79b-410d-a2d4-a8ecce2bfcfd
#
#                                             geometry
# 0  MULTIPOLYGON (((421828.701 636031.199, 421821....
# 1  MULTIPOLYGON (((341524.402 455205.098, 341196....
# 2  MULTIPOLYGON (((496086.6 422477, 497503.596 42...
# 3  POLYGON ((516022.702 412210.895, 515854.099 41...
# 4  POLYGON ((445790.299 252455.405, 444673.802 24...

# %%
lad_gdf.isnull().sum()
# Out:
# LAD24CD       0
# LAD24NM       0
# LAD24NMW    339
# BNG_E         0
# BNG_N         0
# LONG          0
# LAT           0
# GlobalID      0
# geometry      0
# dtype: int64

# %%
#Clean data
lad_gdf.drop('LAD24NMW', axis=1, inplace=True)

# %%
lad_gdf['geometry'] = lad_gdf.geometry.buffer(0)

# %%
lad_gdf.head()
# Out:
#      LAD24CD               LAD24NM   BNG_E   BNG_N     LONG      LAT  \
# 0  E06000001            Hartlepool  447161  531473 -1.27017  54.6761
# 1  E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 2  E06000003  Redcar and Cleveland  464330  519596 -1.00656  54.5675
# 3  E06000004      Stockton-on-Tees  444940  518179 -1.30664  54.5569
# 4  E06000005            Darlington  428029  515648 -1.56835  54.5353
#
#                                GlobalID  \
# 0  8d37e356-5471-457e-879d-d687d4dcd9b5
# 1  30eaef71-04d1-4d40-a8da-8a4e2e7e0891
# 2  a345a607-6a7e-41bd-a268-81e3741ddc76
# 3  d1db01d0-100b-4619-b606-f1208ff4c8cb
# 4  c2cc315b-a5c5-497c-8aa4-2994a4d4820b
#
#                                             geometry
# 0  MULTIPOLYGON (((447097.001 537152.001, 447228....
# 1  MULTIPOLYGON (((449862.75 521262.4, 449853.25 ...
# 2  MULTIPOLYGON (((455939.672 527395.073, 456154....
# 3  MULTIPOLYGON (((444126.099 528005.799, 444165....
# 4  POLYGON ((436388.002 522354.197, 436406.397 52...

# %% [markdown]
# ## Spatial join
# LADs to ITL1 regions

# %%
lad_itl1 = gpd.sjoin(
    lad_gdf,
    itl1_gdf[['ITL125CD','ITL125NM','geometry']],
    how='left',
    predicate='intersects'
)

# %%
lad_itl1
# Out:
#        LAD24CD               LAD24NM   BNG_E   BNG_N     LONG      LAT  \
# 0    E06000001            Hartlepool  447161  531473 -1.27017  54.6761
# 1    E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 1    E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 2    E06000003  Redcar and Cleveland  464330  519596 -1.00656  54.5675
# 2    E06000003  Redcar and Cleveland  464330  519596 -1.00656  54.5675
# ..         ...                   ...     ...     ...      ...      ...
# 357  W06000021         Monmouthshire  337812  209231 -2.90280  51.7783
# 358  W06000022               Newport  337897  187432 -2.89769  51.5823
# 359  W06000023                 Powys  302329  273254 -3.43531  52.3486
# 359  W06000023                 Powys  302329  273254 -3.43531  52.3486
# 360  W06000024        Merthyr Tydfil  305916  206404 -3.36425  51.7484
#
#                                  GlobalID  \
# 0    8d37e356-5471-457e-879d-d687d4dcd9b5
# 1    30eaef71-04d1-4d40-a8da-8a4e2e7e0891
# 1    30eaef71-04d1-4d40-a8da-8a4e2e7e0891
# 2    a345a607-6a7e-41bd-a268-81e3741ddc76
# 2    a345a607-6a7e-41bd-a268-81e3741ddc76
# ..                                    ...
# 357  0093603e-f045-48a3-ad4b-7d73a753d59c
# 358  dc0ab516-4895-494d-ab57-aa5daa137cb7
# 359  56b66698-8bf6-4c1b-b1b5-a43d4ba1ab41
# 359  56b66698-8bf6-4c1b-b1b5-a43d4ba1ab41
# 360  4dd7b72e-0d2b-466d-99a9-90fe5c3e88c0
#
#                                               geometry  index_right ITL125CD  \
# 0    MULTIPOLYGON (((447097.001 537152.001, 447228....            0      TLC
# 1    MULTIPOLYGON (((449862.75 521262.4, 449853.25 ...            2      TLE
# 1    MULTIPOLYGON (((449862.75 521262.4, 449853.25 ...            0      TLC
# 2    MULTIPOLYGON (((455939.672 527395.073, 456154....            2      TLE
# 2    MULTIPOLYGON (((455939.672 527395.073, 456154....            0      TLC
# ..                                                 ...          ...      ...
# 357  MULTIPOLYGON (((327815.5 231026, 327881.5 2309...            4      TLG
# 358  MULTIPOLYGON (((342379.399 194677.603, 342357....            9      TLL
# 359  MULTIPOLYGON (((270878.107 297590.695, 270480....            9      TLL
# 359  MULTIPOLYGON (((270878.107 297590.695, 270480....            4      TLG
# 360  POLYGON ((308057.304 211036.201, 308367.104 20...            9      TLL
#
#                      ITL125NM
# 0        North East (England)
# 1    Yorkshire and The Humber
# 1        North East (England)
# 2    Yorkshire and The Humber
# 2        North East (England)
# ..                        ...
# 357   West Midlands (England)
# 358                     Wales
# 359                     Wales
# 359   West Midlands (England)
# 360                     Wales
#
# [508 rows x 11 columns]

# %%
# Reset index
lad_itl1.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Feature Engineering
#
# compute area, perimeter, compactness

# %%
#area in km^2
lad_itl1['area_km2'] = lad_itl1.geometry.area/1e6

# %%
# perimeter in km
lad_itl1['perimeter_km'] = lad_itl1.geometry.length/1000

# %%
lad_itl1['compactness'] = 4 * np.pi * lad_itl1.geometry.area / (lad_itl1.geometry.length ** 2)

# %%
# Urban/Rural proxy based on median area
median_area = lad_itl1['area_km2'].median()
lad_itl1['urban_rural_proxy'] = np.where(lad_itl1['area_km2'] < median_area, 'More Urban', 'More Rural')
lad_itl1['urban_rural_proxy']
# Out:
# 0      More Urban
# 1      More Urban
# 2      More Urban
# 3      More Urban
# 4      More Urban
#           ...
# 503    More Rural
# 504    More Urban
# 505    More Rural
# 506    More Rural
# 507    More Urban
# Name: urban_rural_proxy, Length: 508, dtype: object

# %%
lad_itl1.head()
# Out:
#      LAD24CD               LAD24NM   BNG_E   BNG_N     LONG      LAT  \
# 0  E06000001            Hartlepool  447161  531473 -1.27017  54.6761
# 1  E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 2  E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 3  E06000003  Redcar and Cleveland  464330  519596 -1.00656  54.5675
# 4  E06000003  Redcar and Cleveland  464330  519596 -1.00656  54.5675
#
#                                GlobalID  \
# 0  8d37e356-5471-457e-879d-d687d4dcd9b5
# 1  30eaef71-04d1-4d40-a8da-8a4e2e7e0891
# 2  30eaef71-04d1-4d40-a8da-8a4e2e7e0891
# 3  a345a607-6a7e-41bd-a268-81e3741ddc76
# 4  a345a607-6a7e-41bd-a268-81e3741ddc76
#
#                                             geometry  index_right ITL125CD  \
# 0  MULTIPOLYGON (((447097.001 537152.001, 447228....            0      TLC
# 1  MULTIPOLYGON (((449862.75 521262.4, 449853.25 ...            2      TLE
# 2  MULTIPOLYGON (((449862.75 521262.4, 449853.25 ...            0      TLC
# 3  MULTIPOLYGON (((455939.672 527395.073, 456154....            2      TLE
# 4  MULTIPOLYGON (((455939.672 527395.073, 456154....            0      TLC
#
#                    ITL125NM    area_km2  perimeter_km  compactness  \
# 0      North East (England)   93.883461     69.630945     0.243329
# 1  Yorkshire and The Humber   53.857000     43.488885     0.357845
# 2      North East (England)   53.857000     43.488885     0.357845
# 3  Yorkshire and The Humber  245.190497     94.986139     0.341502
# 4      North East (England)  245.190497     94.986139     0.341502
#
#   urban_rural_proxy
# 0        More Urban
# 1        More Urban
# 2        More Urban
# 3        More Urban
# 4        More Urban

# %%
#Save processed data
lad_itl1.to_file('lad_itl1.gpkg', driver='GPKG')

# %% [markdown]
# ### Visualisation

# %%
# LADs by ITL1 Region
fig, ax = plt.subplots(1, 1, figsize=(8, 10))
lad_itl1.plot(column='ITL125NM', edgecolor="black", linewidth=0.4, cmap='viridis', ax=ax)
ax.set_title("UK Local Authority Districts by ITL1 Region", fontsize=14)
ax.axis('off')
plt.show()

# %%
# Urban/Rural proxy
lad_itl1.explore(column='urban_rural_proxy', tooltip=['LAD24NM', 'ITL125NM', 'area_km2', 'compactness'],\
                 legend=True, cmap='Spectral')

# %%
lad_itl1.explore('LAD24NM', legend=False)

# %%
# Compactness distribution
plt.figure(figsize=(8,6))
sns.histplot(lad_itl1['compactness'], bins=50, kde=True)
plt.title("Distribution of LAD Compactness")
plt.xlabel("Compactness")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Descriptive Statistics

# %%
# Dropping rows with missing values in numeric columns for aggregation
clean_lad = lad_itl1.dropna(subset=['area_km2','perimeter_km','compactness'])

# %%
itl_summary = clean_lad.groupby('ITL125NM')[['area_km2', 'perimeter_km', 'compactness']].agg(['mean','median','min','max'])
print("Summary by ITL1 Region")
print(itl_summary)
# Out:
# Summary by ITL1 Region
#                              area_km2                                         \
#                                  mean       median         min           max
# ITL125NM
# East (England)             425.004842   332.112162   21.405961   1565.018315
# East Midlands (England)    481.168676   353.580139   23.516736   1766.586356
# London                     109.158442    51.319926    2.882860   1565.018315
# North East (England)      1762.702705   201.209167   53.857000   8040.194060
# North West (England)       964.323400   180.641623   34.873635   8040.194060
# Northern Ireland          1302.691820  1251.072358  137.703100   3012.134963
# Scotland                  2554.776128  1119.936625   59.813871  26157.225736
# South East (England)       378.995551   218.112819   25.367266   3255.368072
# South West (England)       877.711752   663.370746   16.343468   3548.863414
# Wales                     1061.740296   514.799747  108.717861   5195.401234
# West Midlands (England)    612.529712   345.833330   30.833904   5195.401234
# Yorkshire and The Humber   838.059388   363.982752   53.857000   8040.194060
#
#                          perimeter_km                                      \
#                                  mean      median        min          max
# ITL125NM
# East (England)             167.308534  129.905747  25.974833   635.080680
# East Midlands (England)    155.715384  123.697523  30.020171   635.080680
# London                      56.552333   43.485738   9.025031   354.588941
# North East (England)       271.581395  101.583758  43.488885   858.101386
# North West (England)       204.841154  111.345692  34.002897  1116.021256
# Northern Ireland           249.013353  237.846534  64.557426   413.347558
# Scotland                   693.147642  318.409023  47.146390  4781.686286
# South East (England)       128.307272  106.529782  28.106989   556.371889
# South West (England)       237.504135  187.357670  32.979952  1118.616192
# Wales                      267.657571  221.708259  64.673772   666.692110
# West Midlands (England)    164.659143  135.909180  30.130721   590.422182
# Yorkshire and The Humber   185.681262  123.697523  43.488885   858.101386
#
#                          compactness
#                                 mean    median       min       max
# ITL125NM
# East (England)              0.256700  0.251772  0.025833  0.632598
# East Midlands (England)     0.272546  0.278091  0.028482  0.448742
# London                      0.349810  0.345308  0.156415  0.632598
# North East (England)        0.237013  0.236283  0.076713  0.357845
# North West (England)        0.249785  0.265577  0.064940  0.522908
# Northern Ireland            0.260416  0.241548  0.162216  0.415204
# Scotland                    0.175515  0.179291  0.003334  0.354214
# South East (England)        0.270489  0.266938  0.048391  0.535492
# South West (England)        0.201683  0.201797  0.019314  0.468372
# Wales                       0.200160  0.187043  0.045744  0.406134
# West Midlands (England)     0.258861  0.251110  0.111837  0.450190
# Yorkshire and The Humber    0.269221  0.278091  0.066147  0.436608

# %%
# Summary by Urban/Rural
urban_rural_summary = clean_lad.groupby('urban_rural_proxy')[['area_km2','compactness']].agg(['mean','median'])
print("Summary by Urban/Rural Proxy")
print(urban_rural_summary)
# Out:
# Summary by Urban/Rural Proxy
#                       area_km2             compactness
#                           mean      median        mean    median
# urban_rural_proxy
# More Rural         1390.768644  714.783465    0.209881  0.203700
# More Urban          120.216334  103.382683    0.306021  0.309732

# %%
# Area by ITL1 region
plt.figure(figsize=(12,6))
sns.boxplot(data=clean_lad, x='ITL125NM', y='area_km2')
plt.xticks(rotation=45)
plt.title("Distribution of LAD Areas by ITL1 Region")
plt.ylabel("Area(km^2)")
plt.show()

# %% [markdown]
# The distribution of LAD areas varies widely across UK ITL1 regions.
# London has the smallest LADs with relatively uniform sizes.
# Scotland has the largest LADs on average, based on median area.
# Regions like South West and North West show a broad range of district sizes, reflecting a mix of urban and rural areas.

# %%
# Compactness Urban vs Rural
plt.figure(figsize=(8,6))
sns.boxplot(data=clean_lad, x='urban_rural_proxy', y='compactness', palette='Spectral')
plt.title("Compactness Comparison: Urban vs Rural LADs")
plt.show()
# Out:
# C:\Users\alish\AppData\Local\Temp\ipykernel_1840\3638864174.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=clean_lad, x='urban_rural_proxy', y='compactness', palette='Spectral')

# %% [markdown]
# The boxplot compares the compactness values of Local Authority Districts classified as "More Urban" and "More Rural".
# Urban LADs generally have higher compactness values compared to rural LADs,
# suggesting they are more compact and regularly shaped.
# Rural LADs tend to be less compact, likely due to larger and more irregular boundaries.

# %%
# Conclusion 

print("Conclusion / Insights")
print(f"Total LADs: {len(clean_lad)}")
print(f"Median LAD area: {clean_lad['area_km2'].median():.2f} km^2")
print(f"Number of urban LADs: {len(clean_lad[clean_lad['urban_rural_proxy']=='More Urban'])}")
print(f"Number of rural LADs: {len(clean_lad[clean_lad['urban_rural_proxy']=='More Rural'])}")

print("\nInsights by ITL1 region:")
for region in clean_lad['ITL125NM'].unique():
    subset = clean_lad[clean_lad['ITL125NM']==region]
    print(f"{region}: median area = {subset['area_km2'].median():.2f} km^2, median compactness = {subset['compactness'].median():.2f}")
# Out:
# Conclusion / Insights
# Total LADs: 508
# Median LAD area: 308.66 km^2
# Number of urban LADs: 252
# Number of rural LADs: 256
#
# Insights by ITL1 region:
# North East (England): median area = 201.21 km^2, median compactness = 0.24
# Yorkshire and The Humber: median area = 363.98 km^2, median compactness = 0.28
# North West (England): median area = 180.64 km^2, median compactness = 0.27
# East Midlands (England): median area = 353.58 km^2, median compactness = 0.28
# South West (England): median area = 663.37 km^2, median compactness = 0.20
# Wales: median area = 514.80 km^2, median compactness = 0.19
# West Midlands (England): median area = 345.83 km^2, median compactness = 0.25
# South East (England): median area = 218.11 km^2, median compactness = 0.27
# East (England): median area = 332.11 km^2, median compactness = 0.25
# London: median area = 51.32 km^2, median compactness = 0.35
# Scotland: median area = 1119.94 km^2, median compactness = 0.18
# Northern Ireland: median area = 1251.07 km^2, median compactness = 0.24

# %% [markdown]
# Interpretation
#
# - Total LADs: 508, with 252 classified as "More Urban" and 256 as "More Rural".
# - Largest LADs are in Scotland (~1120 km²) and Northern Ireland (~1251 km^2), smallest in London (~51 km^2).
# - Urban LADs are smaller and more compact; rural LADs are larger and less compact.
# - Compactness tends to be higher in urban areas and lower in large rural districts.
